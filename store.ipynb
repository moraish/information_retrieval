# %% [markdown]
# # Initializing Database

# %%
import pandas as pd
import numpy as np
import weaviate

# %%
df = pd.read_csv("/Users/moraish/Desktop/VMWare_Project/vmware-zero-shot-information-retrieval/data/vmware_ir_content.csv")

df.head()
# Out:
#   document_group                                             f_name  \
# 0          tanzu  https---tanzu.vmware.com-solutions-hub-identit...
# 1          tanzu  https---tanzu.vmware.com-solutions-hub-data-ma...
# 2          tanzu  https---tanzu.vmware.com-customers-us-air-forc...
# 3          tanzu  https---tanzu.vmware.com-solutions-hub-monitor...
# 4          tanzu  https---tanzu.vmware.com-solutions-hub-monitor...
#
#                                             raw_text  \
# 0  Black Duck for VMware Tanzu | Solutions Hub | ...
# 1  Percona | Solutions Hub | VMware Tanzu\nSoluti...
# 2  United States Air Force | Customers | VMware T...
# 3  Dynatrace for VMware Tanzu | Solutions Hub | V...
# 4  New Relic for VMware Tanzu | Solutions Hub | V...
#
#                                             raw_meta
# 0  {'onetrust-data-domain': 'b9242434-9feb-47be-a...
# 1  {'onetrust-data-domain': 'b9242434-9feb-47be-a...
# 2  {'onetrust-data-domain': 'b9242434-9feb-47be-a...
# ...

# %%
pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_colwidth', None)  # Display full column content
pd.set_option('display.expand_frame_repr', False)  # Prevent wrapping to new lines

# %%
df.columns
# Out:
# Index(['document_group', 'f_name', 'raw_text', 'raw_meta'], dtype='object')

# %%
df['document_group'].iloc[0]
# Out:
# 'tanzu'

# %%
df['f_name'].iloc[0]
# Out:
# 'https---tanzu.vmware.com-solutions-hub-identity-and-security-black-duck.txt'

# %%
df['raw_text'].iloc[0]
# Out:
# 'Black Duck for VMware Tanzu | Solutions Hub | VMware Tanzu\nSolutions Hub\nBlack Duck for VMware Tanzu\nSecure and Manage Open Source in Your Cloud-Native Applications\nCompatible with\nTAS\nCompatible with TAS\nCan be consumed by apps on TAS\nCompatible with TKG\nCan run on or be consumed by apps on TKG\nCompatible with TKGI\nCan run on or be consumed by apps on TKGI\nBuild fast and stay secure with automated management of the open source software included in your cloud native applications.\nWith the Black Duck Hub Service Broker, you can scan TAS applications as a build step and stay notified of any security vulnerabilities, license, operational risk, or policy violations found in your open source code.\nSecure Your Applications on VMware Tanzu\nIdentify and remediate open source software security vulnerabilities and license violations included with your application code using Black Duck\'s Deep Image Scanning as you deploy to Tanzu.\nRelease Software with Confidence\nWith Black D
# ...

# %%
df['raw_meta'].iloc[0]
# Out:
# "{'onetrust-data-domain': 'b9242434-9feb-47be-a894-3a9e658fdd50', 'microsites-utag': 'https://tags.tiqcdn.com/utag/vmware/microsites-privacy/prod/utag.js', 'titleTag': 'Black Duck for VMware Tanzu | Solutions Hub | VMware Tanzu', 'csrf-param': 'authenticity_token', 'csrf-token': 'NnLorKoXWVAXtOGcZgn6cD0qO7KbHyuGc6QwI0FaGybXtOokYrZEc6scn0I38lWmYcOnFYjUZTpb6w-XsX3bbw', 'DC.Title': 'Black Duck for VMware Tanzu | Solutions Hub', 'DC.Subject': 'paas, platform as a service, agile, mobile, oss', 'DC.Language': 'EN', 'google-site-verification': 'Hzjd9ksxUfQs-ti7CSAoFUmvHvcNHwYT-xtRRhvb5eA', 'facebook-domain-verification': '8sc5peq98k3k11motigpxpzqkksya2', 'DC.Identifier': 'https://tanzu.vmware.com/solutions-hub/identity-and-security/black-duck', 'DC.Format': 'text/html', 'DC.Creator': 'VMware, Inc. or its affiliates', 'DC.Publisher': 'VMware, Inc. or its affiliates', 'DC.Publisher.Address': 'tanzu@vmware.com', 'DC.Contributor': 'VMware, Inc. or its affiliates', 'DC.Date': '2020-03-09', 'DC.T
# ...
